# %% [markdown]
# # Book 1 (Insert name)

# %%
pip install pca
# Out:
# Requirement already satisfied: pca in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (1.9.1)
# Requirement already satisfied: pandas in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (1.4.4)
# Requirement already satisfied: scikit-learn in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (1.0.2)
# Requirement already satisfied: scipy in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (1.9.1)
# Requirement already satisfied: tqdm in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (4.64.1)
# Requirement already satisfied: matplotlib in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (3.5.2)
# Requirement already satisfied: scatterd>=1.2.5 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (1.2.5)
# Requirement already satisfied: statsmodels in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (0.13.2)
# Requirement already satisfied: colourmap>=1.1.10 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (1.1.10)
# Requirement already satisfied: adjustText in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (0.8)
# Requirement already satisfied: numpy in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (1.21.5)
# Requirement already satisfied: wget in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pca) (3.2)
# Requirement already satisfied: requests in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from scatterd>=1.2.5->pca) (2.28.1)
# Requirement already satisfied: seaborn in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from scatterd>=1.2.5->pca) (0.11.2)
# Requirement already satisfied: cycler>=0.10 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pca) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pca) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pca) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pca) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pca) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pca) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->pca) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from pandas->pca) (2022.1)
# Requirement already satisfied: joblib>=0.11 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->pca) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->pca) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from statsmodels->pca) (0.5.2)
# Requirement already satisfied: six in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels->pca) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from requests->scatterd>=1.2.5->pca) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from requests->scatterd>=1.2.5->pca) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from requests->scatterd>=1.2.5->pca) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tobster/opt/anaconda3/lib/python3.9/site-packages (from requests->scatterd>=1.2.5->pca) (1.26.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import itertools
from matplotlib import pyplot as plt
import sklearn
from sklearn.cluster import KMeans, AffinityPropagation, DBSCAN, AgglomerativeClustering
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn import metrics
from sklearn.metrics import davies_bouldin_score, silhouette_score
from sklearn.decomposition import PCA
from pca import pca

# %% [markdown]
# ### Ingest Data

# %%
#Reading the data in from Excel

print("loading data")

twitch_data = pd.read_csv("twitchdata-update.csv")
# Out:
# loading data
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/wf/ykj9yy914c9_jp1vqqp8_yj00000gp/T/ipykernel_38250/1810786697.py in <module>
#       3 print("loading data")
#       4
# ----> 5 twitch_data = pd.read_csv("twitchdata-update.csv")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'twitchdata-update.csv'

# %% [markdown]
# ### Cleaning Data

# %%
#Eliminating non-numeric data & transforming the data to values between 0 and 1

twitch_data['Watch time(Minutes)'].fillna(twitch_data['Watch time(Minutes)'].mean(), inplace=True)
twitch_data['Stream time(minutes)'].fillna(twitch_data['Stream time(minutes)'].mean(), inplace=True)
twitch_data['Peak viewers'].fillna(twitch_data['Peak viewers'].mean(), inplace=True)
twitch_data['Average viewers'].fillna(twitch_data['Average viewers'].mean(), inplace=True)
twitch_data['Followers'].fillna(twitch_data['Followers'].mean(), inplace=True)
twitch_data['Followers gained'].fillna(twitch_data['Followers gained'].mean(), inplace=True)
twitch_data['Views gained'].fillna(twitch_data['Views gained'].mean(), inplace=True)

twitch_data['Partnered'].fillna(twitch_data['Partnered'].value_counts().index[0], inplace=True) #Boolean
twitch_data['Mature'].fillna(twitch_data['Mature'].value_counts().index[0], inplace=True) #Boolean 
twitch_data['Language'].fillna(twitch_data['Language'].value_counts().index[0], inplace=True) #Categorical
twitch_data['Channel'].fillna(twitch_data['Channel'].value_counts().index[0], inplace=True) #Categorical

# %% [markdown]
# ### Categorical Encoding for Data Columns with Strings

# %%
#Categorical Encoding for string columns

cat_encoder = OneHotEncoder()

#twitch_data["Channel"] = twitch_data["Channel"].astype('category')
#twitch_data.dtypes
#twitch_data["Channel_cat"] = twitch_data["Channel"].cat.codes
#twitch_data.head()

twitch_data["Channel"] = twitch_data["Channel"].astype('category')
twitch_data.dtypes
twitch_data["Channel"] = twitch_data["Channel"].cat.codes

twitch_data["Language"] = twitch_data["Language"].astype('category')
twitch_data.dtypes
twitch_data["Language"] = twitch_data["Language"].cat.codes

twitch_data.head()
# Out:
#    Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0      893           6196161750                215250        222720
# 1      872           6091677300                211845        310998
# 2      226           5644590915                515280        387315
# 3      172           3970318140                517740        300575
# 4      600           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature  Language
# 0   False         3
# 1   False         3
# 2    True        14
# 3   False         3
# 4   False         3

# %% [markdown]
# ### Transform Data

# %%
#Scaling Data

#scaled_data = twitch_data[['Watch time(Minutes)', 'Stream time(minutes)', 'Peak viewers', 'Average viewers', 'Followers', 'Followers gained', 'Views gained']]

#for column in scaled_data.columns:
#    scaled_data[column] = (scaled_data[column] - scaled_data[column].min()) / (scaled_data[column].max() - scaled_data[column].min())

scaler = MinMaxScaler()
data_norm = scaler.fit_transform(twitch_data[["Watch time(Minutes)", "Stream time(minutes)", "Peak viewers", "Average viewers", "Followers", "Followers gained", "Views gained", "Partnered", "Mature"]])
norm_names = scaler.get_feature_names_out()
scaled_data = pd.DataFrame(data_norm, columns=norm_names)

twitch_data.describe()
# Out:
#        Watch time(Minutes)  Peak viewers  Average viewers    Followers  \
# count          1000.000000   1000.000000      1000.000000  1000.000000
# mean              0.048771      0.057239         0.030840     0.063389
# std               0.090490      0.094406         0.057349     0.090027
# min               0.000000      0.000000         0.000000     0.000000
# 25%               0.006750      0.013489         0.008295     0.018677
# 50%               0.018571      0.025326         0.014857     0.035187
# 75%               0.051292      0.058029         0.030875     0.069463
# max               1.000000      1.000000         1.000000     1.000000
#
#          Partnered       Mature
# count  1000.000000  1000.000000
# mean      0.978000     0.230000
# std       0.146757     0.421043
# min       0.000000     0.000000
# 25%       1.000000     0.000000
# 50%       1.000000     0.000000
# 75%       1.000000     0.000000
# max       1.000000     1.000000
