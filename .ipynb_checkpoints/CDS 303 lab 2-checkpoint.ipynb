# %%
import numpy as np
import seaborn as sns
import pandas as pd
import itertools
from matplotlib import pyplot as plt
import sklearn
from sklearn.cluster import KMeans, AffinityPropagation, DBSCAN, AgglomerativeClustering
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn import metrics
from sklearn.metrics import davies_bouldin_score, silhouette_score
from sklearn.decomposition import PCA
from pca import pca
import itertools
from sklearn.preprocessing import OneHotEncoder
cat_encoder = OneHotEncoder() 
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth

# %%
########################################################################################################################################################
##  BOOK 1  ############################################################################################################################################
########################################################################################################################################################

#(Ingest)
#Reading the data in from Excel

print("loading data")

twitch_data = pd.read_csv("C:/Users/Sulochan\Downloads/twitchdata-update.csv")

#(Cleaning)
#Eliminating non-numeric data & transforming the data to values between 0 and 1
twitch_data['Watch time(Minutes)'].fillna(twitch_data['Watch time(Minutes)'].mean(), inplace=True)
twitch_data['Peak viewers'].fillna(twitch_data['Peak viewers'].mean(), inplace=True)
twitch_data['Average viewers'].fillna(twitch_data['Average viewers'].mean(), inplace=True)
twitch_data['Followers'].fillna(twitch_data['Followers'].mean(), inplace=True)

twitch_data['Partnered'].fillna(twitch_data['Partnered'].value_counts().index[0], inplace=True) #Boolean
twitch_data['Mature'].fillna(twitch_data['Mature'].value_counts().index[0], inplace=True) #Boolean 
twitch_data['Language'].fillna(twitch_data['Language'].value_counts().index[0], inplace=True) #Categorical
twitch_data['Channel'].fillna(twitch_data['Channel'].value_counts().index[0], inplace=True) #Categorical

#Categorical Encoding for string columns
cat_encoder = OneHotEncoder()
#twitch_data["Channel"] = twitch_data["Channel"].astype('category')
#twitch_data.dtypes
#twitch_data["Channel_cat"] = twitch_data["Channel"].cat.codes
#twitch_data.head()


twitch_data["Channel"] = twitch_data["Channel"].astype('category')
twitch_data.dtypes
twitch_data["Channel"] = twitch_data["Channel"].cat.codes

twitch_data["Language"] = twitch_data["Language"].astype('category')
twitch_data.dtypes
twitch_data["Language"] = twitch_data["Language"].cat.codes

twitch_data.head()


#(Transform)
#Scaling Data
#scaled_data = twitch_data[['Watch time(Minutes)', 'Stream time(minutes)', 'Peak viewers', 'Average viewers', 'Followers', 'Followers gained', 'Views gained']]

#for column in scaled_data.columns:
#    scaled_data[column] = (scaled_data[column] - scaled_data[column].min()) / (scaled_data[column].max() - scaled_data[column].min())

scaler = MinMaxScaler()
data_norm = scaler.fit_transform(twitch_data[["Watch time(Minutes)", "Peak viewers", "Average viewers", "Followers", "Partnered", "Mature", "Stream time(minutes)", "Followers gained", "Views gained", "Language"]])
norm_names = scaler.get_feature_names_out()
twitch_data = pd.DataFrame(data_norm, columns=norm_names)

twitch_data.describe()

#(Transform)
#Scaling Data
#scaled_data = twitch_data[['Watch time(Minutes)', 'Stream time(minutes)', 'Peak viewers', 'Average viewers', 'Followers', 'Followers gained', 'Views gained']]

#for column in scaled_data.columns:
#    scaled_data[column] = (scaled_data[column] - scaled_data[column].min()) / (scaled_data[column].max() - scaled_data[column].min())

scaler = MinMaxScaler()
data_norm = scaler.fit_transform(twitch_data[["Watch time(Minutes)", "Peak viewers", "Average viewers", "Followers", "Partnered", "Mature", "Stream time(minutes)", "Followers gained", "Views gained", "Language"]])
norm_names = scaler.get_feature_names_out()
scaled_data = pd.DataFrame(data_norm, columns=norm_names)

scaled_data.describe()
# Out:
# loading data
# <>:10: DeprecationWarning: invalid escape sequence \D
# <>:10: DeprecationWarning: invalid escape sequence \D
# C:\Users\Sulochan\AppData\Local\Temp/ipykernel_30964/2238630458.py:10: DeprecationWarning: invalid escape sequence \D
#   twitch_data = pd.read_csv("C:/Users/Sulochan\Downloads/twitchdata-update.csv")
#        Watch time(Minutes)  Peak viewers  Average viewers    Followers  \
# count          1000.000000   1000.000000      1000.000000  1000.000000
# mean              0.048771      0.057239         0.030840     0.063389
# std               0.090490      0.094406         0.057349     0.090027
# min               0.000000      0.000000         0.000000     0.000000
# 25%               0.006750      0.013489         0.008295     0.018677
# 50%               0.018571      0.025326         0.014857     0.035187
# 75%               0.051292      0.058029         0.030875     0.069463
# max               1.000000      1.000000         1.000000     1.000000
#
#          Partnered       Mature  Stream time(minutes)  Followers gained  \
# count  1000.000000  1000.000000           1000.000000       1000.000000
# mean      0.978000     0.230000              0.225974          0.055569
# std       0.146757     0.421043              0.164825          0.085356
# min       0.000000     0.000000              0.000000          0.000000
# 25%       1.000000     0.000000              0.135707          0.014949
# 50%       1.000000     0.000000              0.202276          0.028658
# 75%       1.000000     0.000000              0.267151          0.063256
# max       1.000000     1.000000              1.000000          1.000000
#
#        Views gained     Language
# count   1000.000000  1000.000000
# mean       0.017154     0.360950
# std        0.037175     0.280261
# min        0.000000     0.000000
# 25%        0.005530     0.150000
# 50%        0.009374     0.150000
# 75%        0.017943     0.612500
# max        1.000000     1.000000

# %%
########################################################################################################################################################
##  BOOK 2  ############################################################################################################################################
########################################################################################################################################################


#(EDA)
#Creating histograms for all of the variables
    
scaled_data.hist(column=['Watch time(Minutes)'], bins=30)
scaled_data.hist(column=['Stream time(minutes)'], bins=30)
scaled_data.hist(column=['Peak viewers'], bins=30)
scaled_data.hist(column=['Average viewers'], bins=30)
scaled_data.hist(column=['Followers'], bins=30)
scaled_data.hist(column=['Followers gained'], bins=30)
scaled_data.hist(column=['Views gained'], bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'Views gained'}>]], dtype=object)

# %%
twitch_data.dropna(inplace=True)
codes = cat_encoder.fit_transform(twitch_data[["Watch time(Minutes)", "Peak viewers", "Average viewers", "Followers", "Partnered", "Mature", "Stream time(minutes)", "Followers gained", "Views gained", "Language"]])
names = cat_encoder.get_feature_names_out()
codes_df = pd.DataFrame(codes.todense(), columns = names)
data1 = twitch_data.drop(["Watch time(Minutes)", "Peak viewers", "Average viewers", "Followers", "Partnered", "Mature", "Stream time(minutes)", "Followers gained", "Views gained", "Language"], axis=1)
df = pd.merge(codes_df, data1, left_index=True, right_index=True)
df.replace([0,1],[False,True], inplace=True)
df
# Out:
#      Watch time(Minutes)_0.0  Watch time(Minutes)_1.946256260877341e-05  \
# 0                      False                                      False
# 1                      False                                      False
# 2                      False                                      False
# 3                      False                                      False
# 4                      False                                      False
# ..                       ...                                        ...
# 995                    False                                      False
# 996                    False                                      False
# 997                    False                                      False
# 998                    False                                       True
# 999                     True                                      False
#
#      Watch time(Minutes)_4.2718361630070256e-05  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ..                                          ...
# 995                                       False
# 996                                       False
# 997                                        True
# 998                                       False
# 999                                       False
#
#      Watch time(Minutes)_5.447097366599943e-05  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 995                                      False
# 996                                       True
# 997                                      False
# 998                                      False
# 999                                      False
#
#      Watch time(Minutes)_5.4624086073273154e-05  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ..                                          ...
# 995                                        True
# 996                                       False
# 997                                       False
# 998                                       False
# 999                                       False
#
#      Watch time(Minutes)_7.174551058369491e-05  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 995                                      False
# 996                                      False
# 997                                      False
# 998                                      False
# 999                                      False
#
#      Watch time(Minutes)_0.0001535223533989452  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 995                                      False
# 996                                      False
# 997                                      False
# 998                                      False
# 999                                      False
#
#      Watch time(Minutes)_0.00017798576479375813  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ..                                          ...
# 995                                       False
# 996                                       False
# 997                                       False
# 998                                       False
# 999                                       False
#
#      Watch time(Minutes)_0.00017889209146263255  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ..                                          ...
# 995                                       False
# 996                                       False
# 997                                       False
# 998                                       False
# 999                                       False
#
#      Watch time(Minutes)_0.00019312660622941222  ...  Language_0.55  \
# 0                                         False  ...          False
# 1                                         False  ...          False
# 2                                         False  ...          False
# 3                                         False  ...          False
# 4                                         False  ...          False
# ..                                          ...  ...            ...
# 995                                       False  ...          False
# 996                                       False  ...           True
# 997                                       False  ...           True
# 998                                       False  ...          False
# 999                                       False  ...          False
#
#      Language_0.6000000000000001  Language_0.65  Language_0.7000000000000001  \
# 0                          False          False                        False
# 1                          False          False                        False
# 2                          False          False                         True
# 3                          False          False                        False
# 4                          False          False                        False
# ..                           ...            ...                          ...
# 995                        False          False                        False
# 996                        False          False                        False
# 997                        False          False                        False
# 998                        False          False                        False
# 999                        False          False                        False
#
#      Language_0.75  Language_0.8  Language_0.8500000000000001  Language_0.9  \
# 0            False         False                        False         False
# 1            False         False                        False         False
# 2            False         False                        False         False
# 3            False         False                        False         False
# 4            False         False                        False         False
# ..             ...           ...                          ...           ...
# 995          False         False                         True         False
# 996          False         False                        False         False
# 997          False         False                        False         False
# 998          False         False                        False         False
# 999          False         False                        False         False
#
#      Language_0.9500000000000001  Language_1.0
# 0                          False         False
# 1                          False         False
# 2                          False         False
# 3                          False         False
# 4                          False         False
# ..                           ...           ...
# 995                        False         False
# 996                        False         False
# 997                        False         False
# 998                        False         False
# 999                        False         False
#
# [1000 rows x 6901 columns]

# %%
summary_df = pd.DataFrame()                                         
models = ['apriori', 'fpmax', 'fpgrowth']                           
param_list = np.linspace(.1, .9, 8)                                 
min_support = .1                                                    
i = 0                                                               
model_set = [                                                       
    apriori(df, min_support, max_len = 3, use_colnames=True),
    fpmax(df, min_support, max_len = 3, use_colnames=True), 
    fpgrowth(df, min_support, max_len = 3, use_colnames=True)
    ]

for model in model_set:
    for k in range(len(param_list)):
        min_support = param_list[k]                                 
        model_df = pd.DataFrame(model)                              
        model_df['model'] = models[i]                              
        summary_df = pd.concat([summary_df, model_df], axis=0)     
    i = i + 1                                                       
summary_df.reset_index(inplace=True, drop=True)  

summary_df
# Out:
#      support                                           itemsets     model
# 0      0.978                                    (Partnered_1.0)   apriori
# 1      0.770                                       (Mature_0.0)   apriori
# 2      0.230                                       (Mature_1.0)   apriori
# 3      0.485                     (Language_0.15000000000000002)   apriori
# 4      0.753                        (Partnered_1.0, Mature_0.0)   apriori
# ..       ...                                                ...       ...
# 187    0.349         (Language_0.15000000000000002, Mature_0.0)  fpgrowth
# 188    0.343  (Language_0.15000000000000002, Mature_0.0, Par...  fpgrowth
# 189    0.225                        (Partnered_1.0, Mature_1.0)  fpgrowth
# 190    0.136         (Language_0.15000000000000002, Mature_1.0)  fpgrowth
# 191    0.133  (Language_0.15000000000000002, Mature_1.0, Par...  fpgrowth
#
# [192 rows x 3 columns]

# %%
from mlxtend.frequent_patterns import association_rules

assoc_df = association_rules(summary_df, metric="confidence", min_threshold=0.7)
assoc_df1 = assoc_df[
    (assoc_df['lift'] > .75) &
    (assoc_df['conviction'] > 1)]
assoc_df1
# Out:
#                                   antecedents      consequents  \
# 2                                (Mature_1.0)  (Partnered_1.0)
# 3              (Language_0.15000000000000002)  (Partnered_1.0)
# 5  (Language_0.15000000000000002, Mature_0.0)  (Partnered_1.0)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 2               0.230               0.978    0.225    0.978261  1.000267
# 3               0.485               0.978    0.476    0.981443  1.003521
# 5               0.349               0.978    0.343    0.982808  1.004916
#
#    leverage  conviction
# 2  0.000060    1.012000
# 3  0.001670    1.185556
# 5  0.001678    1.279667
